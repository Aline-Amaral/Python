# %%
# 1. Classe Bola: Crie uma classe que modele uma bola:
# a. Atributos: Cor, circunferência, material

class Bola:
    def __init__(self, cor, circunferencia, material):
        self.cor = cor
        self.circunferencia = circunferencia
        self.material = material
        
# b. Métodos: trocaCor e mostraCor

    def trocaCor(self, novaCor):
        self.cor = novaCor
        print(f"A nova cor da bola é: {self.cor}")
        
    def mostraCor(self):
        print(f"A cor da bola é: {self.cor}")
        

bola = Bola('azul', 10, 'borracha')
bola.mostraCor()

bola.trocaCor('vermelha')
# Out:
# A cor da bola é: azul
# A nova cor da bola é: vermelha

# %%
# 2. Classe Quadrado: Crie uma classe que modele um quadrado:
# a. Atributos: Tamanho do lado

class Quadrado:
    def __init__(self, lado):
        self.lado = lado

# b. Métodos: Mudar valor do Lado, Retornar valor do Lado e calcular Área;

    def mudarLado(self, novoLado):
        self.lado = novoLado
        print(f"O novo valor do lado é: {self.lado}")
        
    def obterLado(self):
        print(f"O valor do lado é: {self.lado}")
        
    def calcularArea(self):
        area = self.lado * self.lado
        print(f"O valor da área do quadrado é: {area}")
        
quadrado = Quadrado(2)
quadrado.obterLado()
quadrado.calcularArea()

quadrado.mudarLado(5)
quadrado.obterLado()
quadrado.calcularArea()
# Out:
# O valor do lado é: 2
# O valor da área do quadrado é: 4
# O novo valor do lado é: 5
# O valor do lado é: 5
# O valor da área do quadrado é: 25

# %%
# 3. Classe Retangulo: Crie uma classe que modele um retangulo:
# a. Atributos: LadoA, LadoB (ou Comprimento e Largura, ou comprimento e largura, a
# escolher)4

class Retangulo:
    def __init__(self, comprimento, largura):
        self.comprimento = comprimento
        self.largura = largura

# b. Métodos: Mudar valor dos lados, Retornar valor dos lados, calcular Área e calcular
# Perímetro;

    def mudarValores(self, novoComprimento, novaLargura):
        self.comprimento = novoComprimento
        self.largura = novaLargura
        print(f"O novo valor da comprimento é: {self.comprimento} e o valor da largura é: {self.largura}")
    
    def obterValores(self):
        print(f"O valor da comprimento é: {self.comprimento} e o valor da largura é: {self.largura}")
        
    def calcularArea(self):
        area = self.comprimento * self.largura
        return area
    
    def calcularPerimetro(self):
        perimetro = (2 * self.comprimento) + (2 * self.largura)
        return perimetro

# c. Crie um programa que utilize esta classe. Ele deve pedir ao usuário que informe
# as medidas de um local. Depois, deve criar um objeto com as medidas e
# calcular a quantidade de pisos e de rodapés necessárias para o local.

comprimento = int(input("Digite o comprimento do local: "))
largura = int(input("Digite a largura do local: "))

medidasLocal = Retangulo(comprimento, largura)

print(f"Serão necessários {medidasLocal.calcularArea()} metros quadrados de pisos.")
print(f"Serão necessários {medidasLocal.calcularPerimetro()} metros de rodapés.")
# Out:
# Digite o comprimento do local: 4
# Digite a largura do local: 5
# Serão necessários 20 metros quadrados de pisos.
# Serão necessários 18 metros de rodapés.

# %%
# 4. Classe Pessoa: Crie uma classe que modele uma pessoa:
# a. Atributos: nome, idade, peso e altura

class Pessoa:
    def __init__(self, nome, idade, peso, altura):
        self.nome = nome
        self.idade = idade
        self.peso = peso
        self.altura = altura
    
# b. Métodos: Envelhecer, engordar, emagrecer, crescer. Obs: Por padrão, a cada
# ano que nossa pessoa envelhece, sendo a idade dela menor que 21 anos, ela
# deve crescer 0,5 cm.

    def envelhecer(self, anos):
        idade = self.idade + anos
        return idade
    
    def engordar(self, quilos):
        novoPeso = self.peso + quilos
        return novoPeso
        
    def emagrecer(self, quilos):
        novoPeso = self.peso - quilos
        return novoPeso
    
    def crescer(self):
        if (self.idade < 21): 
            self.altura += 0.5
        return self.idade

pessoa = Pessoa('Joaquim', 7, 30, 1.1)

# %%
# 5. Crie um programa que tenha uma classe Carro. Este programa deve ter no mínimo 3
# propriedades para a classe carro e no mínimo 3 métodos para ela, sendo um destes
# métodos para imprimir todos os dados de um carro.
# a. Crie 3 objetos para carros diferentes que recebem como entrada os parâmetros
# das propriedades que você definiu

class Carro:
    def __init__(self, marca, ano, cor):
        self.marca = marca
        self.ano = ano
        self.cor = cor

    def dados(self):
        return (f"Carro da marca: {self.marca}; Ano: {self.ano}; E cor: {self.cor}.")

    def trocarCor(self, novaCor):
        self.cor = novaCor
        print(f"A nova cor do carro é: {self.cor}")

    def obterAno(self):
        print (f"O ano do carro é: {self.ano}")


carro1 = Carro("VW", 2012, "vermelho")
carro2 = Carro("Ford", 2022, "preto")
carro3 = Carro("Nissan", 1998, "prata")

# b. Consulte cada um desses parâmetros para cada um dos objetos criados no
# exercício anterior

print(f"Dados do Carro 1-> {carro1.dados()}")
print(f"Dados do Carro 2-> {carro2.dados()}")
print(f"Dados do Carro 3-> {carro3.dados()}")

# c. Chame cada um dos métodos criados para verificar o correto funcionamento

carro1.trocarCor("branco")
carro3.obterAno()
